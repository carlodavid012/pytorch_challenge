# %%
#install pytorch
# !pip3 install -U -q http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
# Out:
# tcmalloc: large alloc 1073750016 bytes == 0x577aa000 @  0x7f4d5d37b2a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641

# %%
pip3 install torchvision
# Out:
#   File "<ipython-input-128-5589d0d10cb2>", line 1
#     pip3 install torchvision
#                ^
# SyntaxError: invalid syntax

# %%
import torch
import numpy as np

# %%
def activation(x):
  
  #sigmoid activation function
  
  return 1/(1+torch.exp(-x))

# %%
# Generate some data
torch.manual_seed(0)

# Features are 5 random normal variables
features = torch.randn((1, 5))

# True weights for our data, random normal variables again
weights = torch.randn_like(features)

# bias term
bias = torch.randn((1, 1))

# %%
# Calculate the output of this network
y = activation(torch.sum(features * weights) + bias)

# %%
# another way of calculating using matrix multiplication
y = activation(torch.mm(features, weights.view(5,1)) + bias)

# %%
## Multi-layer neural network

# %%
# Generate some data
torch.manual_seed(7)

# Features are 3 random normal variables
features = torch.randn((1, 3))

# Define the size of each layer in our network
n_input = features.shape[1]
n_hidden = 2
n_output = 1

# Weights for inputs to hidden layer
W1 = torch.randn(n_input, n_hidden)

# Weights for hidden layer to output layer
W2 = torch.randn(n_hidden, n_output)

# bias term for hidden and output layers
B1 = torch.randn((1, n_hidden))
B2 = torch.randn((1, n_output))

# %%
# Calculate the output
h = activation(torch.mm(features, W1) + B1)
output = activation(torch.mm(h, W2) + B2)
print(output)
# Out:
# tensor([[0.3171]])

# %%
## Numpy to Torch and back

# %%
a = np.random.rand(4,3)
a
# Out:
# array([[0.105705  , 0.49425214, 0.25198057],
#        [0.99051662, 0.45098089, 0.07267056],
#        [0.94869642, 0.75590154, 0.36860888],
#        [0.24776968, 0.03193834, 0.02188337]])

# %%
b = torch.from_numpy(a)
b
# Out:
# tensor([[0.1057, 0.4943, 0.2520],
#         [0.9905, 0.4510, 0.0727],
#         [0.9487, 0.7559, 0.3686],
#         [0.2478, 0.0319, 0.0219]], dtype=torch.float64)

# %%
b.numpy()
# Out:
# array([[0.105705  , 0.49425214, 0.25198057],
#        [0.99051662, 0.45098089, 0.07267056],
#        [0.94869642, 0.75590154, 0.36860888],
#        [0.24776968, 0.03193834, 0.02188337]])

# %%
b.mul_(2)
# Out:
# tensor([[0.2114, 0.9885, 0.5040],
#         [1.9810, 0.9020, 0.1453],
#         [1.8974, 1.5118, 0.7372],
#         [0.4955, 0.0639, 0.0438]], dtype=torch.float64)

# %%
a
# Out:
# array([[0.21141   , 0.98850429, 0.50396114],
#        [1.98103323, 0.90196179, 0.14534112],
#        [1.89739283, 1.51180308, 0.73721776],
#        [0.49553937, 0.06387668, 0.04376673]])
